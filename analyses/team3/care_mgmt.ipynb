# %%
#################
# Load Packages #
#################

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import generateGraphs

# %matplotlib inline

# %%
#################
#  Description  #
#################
#Analyze care management table and develop basic forecast
#Unfortunately didn't have time to study benefits column

# %%
########################
#  Data Normalization  #
#  And Exploration     #
########################

careMgmt = pd.read_csv("care_management_anonymized.csv")
careMgmt['assistance_date'] = pd.to_datetime(careMgmt['assistance_date']) #convert to DateTime date
#careMgmt['assistance_date'].max() #find max date

# %%
#look at most popular assistance categories
careMgmt['assistance_category'].value_counts()
# Out:
# Remote Contact with client (phone, email)    8736
# Remote Contact w/o client                    1948
# Home Visit                                    766
# Community                                     757
# Internal Discussions                          233
# ElderNet Office                                47
# Name: assistance_category, dtype: int64

# %%
#################
# Data Analysis #
#################

#form list of subcategories for graphs
listOfCareMgmtCategories = ['Remote Contact with client (phone, email)',
       'Home Visit', 'Community', 'Remote Contact w/o client',
       'Internal Discussions']

generateGraphs.generateGraphSet(dataFrameNameForTitle = 'Care Management', df = careMgmt, dateColumn='assistance_date',specialColumnForCategory ='assistance_category', 
                                listOfCategories= listOfCareMgmtCategories, columnForAnalysis='amount', 
                                yAxisNameForGraph= 'Amount of Contacts', isSummed='No')
